# %% [markdown]
# ### DSAA Lab Work/ Exercise5
# ### Made by: Parth Kalia
# ### 21BAI10109

# %%
locations = []

for i in range(21):
    x = input(f"Enter {i}")
    locations.append(x)
    print(x)
locations
# Out:
# Gwalior
# Shivpuri
# Orchha
# Khajuraho
# Chitrakoot
# Sanchi
# Satna
# Ujjain
# Bhopal
# Jabalpur
# Bandhavgarh
# Indore
# Bhojpur
# Marble Rocks
# Mandu
# Omkareshwar
# Bhimbetka
# Panchmarhi
# Amarkantak
# Kanha
# Nagpur
# ['Gwalior',
#  'Shivpuri',
#  'Orchha',
#  'Khajuraho',
#  'Chitrakoot',
#  'Sanchi',
#  'Satna',
#  'Ujjain',
#  'Bhopal',
#  'Jabalpur',
#  'Bandhavgarh',
#  'Indore',
#  'Bhojpur',
#  'Marble Rocks',
#  'Mandu',
#  'Omkareshwar',
#  'Bhimbetka',
#  'Panchmarhi',
#  'Amarkantak',
#  'Kanha',
#  'Nagpur']

# %%
locations = [
    "Gwalior",
    "Shivpuri",
    "Orchha",
    "Khajuraho",
    "Chitrakoot",
    "Sanchi",
    "Satna",
    "Ujjain",
    "Bhopal",
    "Jabalpur",
    "Bandhavgarh",
    "Indore",
    "Bhojpur",
    "Marble Rocks",
    "Mandu",
    "Omkareshwar",
    "Bhimbetka",
    "Panchmarhi",
    "Amarkantak",
    "Kanha",
    "Nagpur"
]

list(enumerate(locations))

edges = []
x = ''
while x!='q':
    x = input()
    if x!= 'q':
        edges.append(tuple(map(int, x.split())))
    print(edges)
# Out:
# [(0, 1, 112)]
# [(0, 1, 112), (0, 2, 119)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170), (3, 6, 117)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170), (3, 6, 117), (4, 6, 100)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170), (3, 6, 117), (4, 6, 100), (4, 10, 196)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170), (3, 6, 117), (4, 6, 100), (4, 10, 196), (5, 8, 46)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170), (3, 6, 117), (4, 6, 100), (4, 10, 196), (5, 8, 46), (6, 9, 200)]
# [(0, 1, 112), (0, 2, 119), (1, 7, 343), (1, 8, 311), (2, 3, 170), (3, 6, 117), (4, 6, 100), (4, 10, 196), (5, 8, 46), (6, 9, 200), (7, 11, 55)]
# ...

# %%
locations = [
    "Gwalior",
    "Shivpuri",
    "Orchha",
    "Khajuraho",
    "Chitrakoot",
    "Sanchi",
    "Satna",
    "Ujjain",
    "Bhopal",
    "Jabalpur",
    "Bandhavgarh",
    "Indore",
    "Bhojpur",
    "Marble Rocks",
    "Mandu",
    "Omkareshwar",
    "Bhimbetka",
    "Panchmarhi",
    "Amarkantak",
    "Kanha",
    "Nagpur"
]

edges = [
    (0, 1, 112),
    (0, 2, 119), 
    (1, 7, 343),
    (1, 8, 311),
    (2, 3, 170),
    (3, 6, 117),
    (4, 6, 100),
    (4, 10, 196),
    (5, 8, 46),
    (6, 9, 200),
    (7, 11, 55),
    (7, 11, 55),
    (8, 11, 186),
    (8, 12, 28),
    (9, 10, 190),
    (9, 13, 23),
    (9, 19, 185),
    (9, 20, 200),
    (10, 18, 195),
    (11, 14, 99),
    (11, 15, 80),
    (12, 16, 40),
    (13, 17, 221),
    (16, 17, 151),
    (17, 19, 337),
    (17, 20, 300),
    (18, 19, 238),
    (19, 20, 250)
]

enum_locations = list(enumerate(locations))
enum_locations
# Out:
# [(0, 'Gwalior'),
#  (1, 'Shivpuri'),
#  (2, 'Orchha'),
#  (3, 'Khajuraho'),
#  (4, 'Chitrakoot'),
#  (5, 'Sanchi'),
#  (6, 'Satna'),
#  (7, 'Ujjain'),
#  (8, 'Bhopal'),
#  (9, 'Jabalpur'),
#  (10, 'Bandhavgarh'),
#  (11, 'Indore'),
#  (12, 'Bhojpur'),
#  (13, 'Marble Rocks'),
#  (14, 'Mandu'),
#  (15, 'Omkareshwar'),
#  (16, 'Bhimbetka'),
#  (17, 'Panchmarhi'),
#  (18, 'Amarkantak'),
#  (19, 'Kanha'),
#  (20, 'Nagpur')]

# %%
enum_locations = [
    (0, 'Gwalior'),
    (1, 'Shivpuri'),
    (2, 'Orchha'),
    (3, 'Khajuraho'),
    (4, 'Chitrakoot'),
    (5, 'Sanchi'),
    (6, 'Satna'),
    (7, 'Ujjain'),
    (8, 'Bhopal'),
    (9, 'Jabalpur'),
    (10, 'Bandhavgarh'),
    (11, 'Indore'),
    (12, 'Bhojpur'),
    (13, 'Marble Rocks'),
    (14, 'Mandu'),
    (15, 'Omkareshwar'),
    (16, 'Bhimbetka'),
    (17, 'Panchmarhi'),
    (18, 'Amarkantak'),
    (19, 'Kanha'),
    (20, 'Nagpur')
]


edges = [
    (0, 1, 112),
    (0, 2, 119), 
    (1, 7, 343),
    (1, 8, 311),
    (2, 3, 170),
    (3, 6, 117),
    (4, 6, 100),
    (4, 10, 196),
    (5, 8, 46),
    (6, 9, 200),
    (7, 11, 55),
    (8, 11, 186),
    (8, 12, 28),
    (9, 10, 190),
    (9, 13, 23),
    (9, 19, 185),
    (9, 20, 200),
    (10, 18, 195),
    (11, 14, 99),
    (11, 15, 80),
    (12, 16, 40),
    (13, 17, 221),
    (16, 17, 151),
    (17, 19, 337),
    (17, 20, 300),
    (18, 19, 238),
    (19, 20, 250)
]

len(edges)
# Out:
# 27

# %%
for i, j in enum_locations:
    city_info = f'{j}'
    for k, l, m in edges:
        if k == i:
            city_info += f' -> {enum_locations[l][1]} ({m})'
        if l == i:
            city_info += f' -> {enum_locations[k][1]} ({m})'
    print(city_info)
# Out:
# Gwalior -> Shivpuri (112) -> Orchha (119)
# Shivpuri -> Gwalior (112) -> Ujjain (343) -> Bhopal (311)
# Orchha -> Gwalior (119) -> Khajuraho (170)
# Khajuraho -> Orchha (170) -> Satna (117)
# Chitrakoot -> Satna (100) -> Bandhavgarh (196)
# Sanchi -> Bhopal (46)
# Satna -> Khajuraho (117) -> Chitrakoot (100) -> Jabalpur (200)
# Ujjain -> Shivpuri (343) -> Indore (55)
# Bhopal -> Shivpuri (311) -> Sanchi (46) -> Indore (186) -> Bhojpur (28)
# Jabalpur -> Satna (200) -> Bandhavgarh (190) -> Marble Rocks (23) -> Kanha (185) -> Nagpur (200)
# Bandhavgarh -> Chitrakoot (196) -> Jabalpur (190) -> Amarkantak (195)
# Indore -> Ujjain (55) -> Bhopal (186) -> Mandu (99) -> Omkareshwar (80)
# Bhojpur -> Bhopal (28) -> Bhimbetka (40)
# Marble Rocks -> Jabalpur (23) -> Panchmarhi (221)
# Mandu -> Indore (99)
# Omkareshwar -> Indore (80)
# Bhimbetka -> Bhojpur (40) -> Panchmarhi (151)
# Panchmarhi -> Marble Rocks (221) -> Bhimbetka (151) -> Kanha (337) -> Nagpur (300)
# ...
